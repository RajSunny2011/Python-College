# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn import preprocessing
from sklearn.model_selection import train_test_split,cross_val_score,StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.impute import KNNImputer

import missingno as msn

# %%
data = pd.read_csv('supermarket_sales1.csv')
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty         NaN       NaN  26.1415   548.9715
# 1    Electronic accessories       15.28       5.0   3.8200    80.2200
# ...

# %%
# data.dropna(inplace=True)
df = data.dropna()
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 1    Electronic accessories       15.28       5.0   3.8200    80.2200
# 4         Sports and travel       86.31       7.0  30.2085   634.3785
# ...

# %%
# data.fillna({'Unit price': round(data['Unit price'].mean(),2),'Quantity': int(data['Quantity'].mean())})
# data.fillna({'Unit price': round(data['Unit price'].mean(),2),'Quantity': int(data['Quantity'].mean())},inplace=True)
data['Unit price'] = data['Unit price'].fillna(round(data['Unit price'].mean(),2))
data['Quantity'] = data['Quantity'].fillna(round(data['Quantity'].mean(),0))
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       55.65       6.0  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28       5.0   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33       6.0  16.2155  340.5255   3/3/2019
# 3       Health and beauty       55.65       8.0  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31       7.0  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data['Unit price'] = data['Unit price'].fillna(round(data['Unit price'].median(),2))
data['Quantity'] = data['Quantity'].fillna(round(data['Quantity'].median(),2))
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       55.06       5.0  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28       5.0   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33       5.0  16.2155  340.5255   3/3/2019
# 3       Health and beauty       55.06       8.0  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31       7.0  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data['Unit price'] = data['Unit price'].fillna(round(data['Unit price'].mode()[0],2))
data['Quantity'] = data['Quantity'].fillna(round(data['Quantity'].mode()[0],2))
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       83.77      10.0  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28       5.0   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33      10.0  16.2155  340.5255   3/3/2019
# 3       Health and beauty       83.77       8.0  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31       7.0  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
q1 = data['Unit price'].quantile(0.25)
lower_bound = q1
q1
# Out:
# 32.875

# %%
q3 = data['Unit price'].quantile(0.75)
upper_bound = q3
q3
# Out:
# 77.935

# %%
IQR = q3-q1
IQR
# Out:
# 45.06

# %%
data = data[(data['Unit price']>lower_bound) & (data['Unit price']<upper_bound)]
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       55.65       6.0  26.1415  548.9715   1/5/2019
# 2      Home and lifestyle       46.33       6.0  16.2155  340.5255   3/3/2019
# 3       Health and beauty       55.65       8.0  23.2880  489.0480  1/27/2019
# 6  Electronic accessories       68.84       6.0  20.6520  433.6920  2/25/2019
# 7      Home and lifestyle       73.56      10.0  36.7800  772.3800  2/24/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data['Unit price'] = np.where(data['Unit price']>upper_bound, upper_bound, data['Unit price'])
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty      77.935      10.0  26.1415  548.9715   1/5/2019
# 1  Electronic accessories      15.280       5.0   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle      46.330      10.0  16.2155  340.5255   3/3/2019
# 3       Health and beauty      77.935       8.0  23.2880  489.0480  1/27/2019
# 4       Sports and travel      77.935       7.0  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data['Unit price'] = np.where(data['Unit price']<lower_bound, lower_bound, data['Unit price'])
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty      77.935      10.0  26.1415  548.9715   1/5/2019
# 1  Electronic accessories      32.875       5.0   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle      46.330      10.0  16.2155  340.5255   3/3/2019
# 3       Health and beauty      77.935       8.0  23.2880  489.0480  1/27/2019
# 4       Sports and travel      77.935       7.0  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data['Unit price'] = np.log(data['Unit price'])
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty    4.355875      10.0  26.1415   548.9715
# 1    Electronic accessories    3.492712       5.0   3.8200    80.2200
# ...

# %%
imputer = KNNImputer(n_neighbors=2)
data_imputed = imputer.fit_transform(pd.DataFrame(data['Unit price']))
data['Unit price'] = data_imputed
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty   55.650521       NaN  26.1415   548.9715
# 1    Electronic accessories   15.280000       5.0   3.8200    80.2200
# ...
