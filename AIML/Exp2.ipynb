# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('supermarket_sales copy.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     999 non-null    object
#  3   Customer type            999 non-null    object
#  4   Gender                   999 non-null    object
#  5   Product line             999 non-null    object
#  6   Unit price               998 non-null    float64
#  7   Quantity                 998 non-null    float64
#  8   Tax 5%                   999 non-null    float64
#  9   Total                    1000 non-null   float64
#  10  Date                     999 non-null    object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     999 non-null    float64
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal     NaN
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69       7.0  26.1415  548.9715   1/5/2019
# 1  Electronic accessories         NaN       5.0   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33       7.0  16.2155  340.5255   3/3/2019
# 3       Health and beauty         NaN       NaN  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31       7.0  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.describe()
# Out:
#        Unit price    Quantity      Tax 5%        Total        cogs  \
# count   998.00000  998.000000  999.000000  1000.000000  999.000000
# mean     55.71005    5.512024   15.359597   322.966749  307.818799
# std      26.49017    2.921809   11.697976   245.885335  234.179371
# min      10.08000    1.000000    0.508500    10.678500   10.170000
# 25%      32.97500    3.000000    5.894750   124.422375  119.320000
# 50%      55.23000    5.000000   12.080000   253.848000  241.920000
# 75%      77.94500    8.000000   22.429000   471.350250  449.210000
# max      99.96000   10.000000   49.650000  1042.650000  993.000000
#
#        gross margin percentage  gross income      Rating
# count             9.990000e+02    999.000000  1000.00000
# mean              4.761905e+00     15.391713     6.97270
# std               8.886233e-16     11.708178     1.71858
# min               4.761905e+00      0.508500     4.00000
# 25%               4.761905e+00      5.966000     5.50000
# ...

# %%
df.isnull()
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False    True         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 995       False   False  False          False   False         False
# 996       False   False  False          False   False         False
# 997       False   False  False          False   False         False
# 998       False   False  False          False   False         False
# 999       False   False  False           True   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0         False     False   False  False  False  False    False  False
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       1
# Customer type              1
# Gender                     1
# Product line               1
# Unit price                 2
# Quantity                   2
# Tax 5%                     1
# Total                      0
# Date                       1
# Time                       0
# Payment                    0
# cogs                       1
# gross margin percentage    1
# gross income               1
# Rating                     0
# dtype: int64

# %%
# df.dropna(inplace=True)

# %%
df.fillna({'Unit price':round(df['Unit price'].mean(),2), 'Quantity':round(df['Quantity'].mean(),0), 'cogs':round(df['cogs'].mean(),2)}, inplace=True)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal     NaN
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69       7.0  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       55.71       5.0   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33       7.0  16.2155  340.5255   3/3/2019
# 3       Health and beauty       55.71       6.0  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31       7.0  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sns.histplot(df['Unit price'])
plt.show()

# %%
sns.boxplot(x='Payment',y='Unit price', data=df)
plt.show()

# %%
sns.scatterplot(x='cogs', y='Unit price', data= df)
plt.show()

# %%
sns.countplot(x='Branch', data=df)
plt.show()

# %%
af = df[['Unit price','Quantity','Tax 5%','cogs','gross income','Rating']]
corr = af.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
df.groupby('City')['Quantity'].mean()
# Out:
# City
# Mandalay     5.481928
# Naypyitaw    5.596330
# Yangon       5.461765
# Name: Quantity, dtype: float64

# %%
pd.pivot_table(df, values='Quantity', index='Branch', columns='Product line')
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                           5.372881             5.156863            5.396552
# B                           5.745455             4.790323            5.400000
# C                           6.145455             5.261538            5.590909
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                      5.425532            5.707692           5.644068
# B                      6.037736            5.900000           5.193548
# C                      5.326923            5.444444           5.888889
