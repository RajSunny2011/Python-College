# %%
import matplotlib.pyplot as plt

l1 = [(1, 0.000002),(10, 0.000000),(100, 0.000001),(1000, 0.000007),(10000, 0.000053),(100000, 0.000523),(1000000, 0.002549),(10000000, 0.020336),(100000000, 0.206882),(1000000000, 2.051216)]
l2 = [(1, 0.000003),(10, 0.000001),(100, 0.000001),(1000, 0.000004),(10000, 0.000028),(100000, 0.000335),(1000000, 0.001702),(10000000, 0.011704),(100000000, 0.120875),(1000000000, 1.211290)]
plt.plot(*zip(*l1))
plt.plot(*zip(*l2))

plt.show()
